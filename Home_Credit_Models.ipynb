# %% [markdown]
# This is a jupyter notebook solving Home Credit Default problems using Logistic Regression, Random Forest and Gradient Boosting models.

# %%
import numpy as np
import pandas as pd
from scipy import stats
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
import os
import warnings
warnings.simplefilter('ignore')

from IPython.display import display, HTML

# from imputer import Imputer
from sklearn.preprocessing import Imputer
from missingpy import KNNImputer
import lightgbm as lgb
from sklearn.svm import LinearSVC
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
from sklearn.preprocessing import LabelBinarizer, LabelEncoder, StandardScaler, RobustScaler
from sklearn.linear_model import SGDClassifier, LogisticRegression
from sklearn.metrics import roc_auc_score
from sklearn.ensemble import RandomForestClassifier

from memory_profiler import profile

# %%
path = '../home_credit_data/'

# %%
df = pd.read_csv(path+'/home_credit_processed.csv')

# %% [markdown]
# ## Data Cleaning
#
# Since Logistic Regression model have the requirement that data cannot contains NA. We do more data preprocessing here.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 356251 entries, 0 to 356250
# Columns: 799 entries, Unnamed: 0 to CC_COUNT
# dtypes: float64(622), int64(177)
# memory usage: 2.1 GB

# %%
# checking missing data
total = df.isnull().sum().sort_values(ascending = False)
percent = (df.isnull().sum()/df.isnull().count()*100).sort_values(ascending = False)
missing_data  = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(20)
# Out:
#                                     Total    Percent
# REFUSED_RATE_DOWN_PAYMENT_MEAN     303648  85.234287
# REFUSED_AMT_DOWN_PAYMENT_MIN       303648  85.234287
# REFUSED_RATE_DOWN_PAYMENT_MAX      303648  85.234287
# REFUSED_RATE_DOWN_PAYMENT_MIN      303648  85.234287
# REFUSED_AMT_DOWN_PAYMENT_MEAN      303648  85.234287
# REFUSED_AMT_DOWN_PAYMENT_MAX       303648  85.234287
# REFUSED_APP_CREDIT_PERC_VAR        298034  83.658432
# CC_AMT_PAYMENT_CURRENT_VAR         284649  79.901249
# CC_CNT_DRAWINGS_ATM_CURRENT_VAR    284559  79.875986
# CC_AMT_DRAWINGS_ATM_CURRENT_VAR    284559  79.875986
# CC_AMT_DRAWINGS_OTHER_CURRENT_VAR  284559  79.875986
# CC_CNT_DRAWINGS_POS_CURRENT_VAR    284559  79.875986
# CC_AMT_DRAWINGS_POS_CURRENT_VAR    284559  79.875986
# CC_CNT_DRAWINGS_OTHER_CURRENT_VAR  284559  79.875986
# CC_AMT_PAYMENT_CURRENT_MEAN        284131  79.755846
# CC_AMT_PAYMENT_CURRENT_MAX         284131  79.755846
# CC_AMT_PAYMENT_CURRENT_MIN         284131  79.755846
# CC_AMT_DRAWINGS_OTHER_CURRENT_MAX  284057  79.735074
# CC_AMT_DRAWINGS_ATM_CURRENT_MEAN   284057  79.735074
# CC_AMT_DRAWINGS_OTHER_CURRENT_MIN  284057  79.735074

# %%
df.shape
# Out:
# (356251, 799)

# %% [markdown]
# Get the most important 150 features and check for the NAN values.

# %%
index = pd.read_csv('features_selected.csv')

# %%
index
# Out:
#                                            feature  importance
# 0                                     PAYMENT_RATE        1201
# 1                                     EXT_SOURCE_3         872
# 2                                     EXT_SOURCE_1         822
# 3                                     EXT_SOURCE_2         776
# 4                                       DAYS_BIRTH         735
# 5                                    DAYS_EMPLOYED         535
# 6                                      AMT_ANNUITY         511
# 7                           ACTIVE_DAYS_CREDIT_MAX         469
# 8                    INSTAL_DAYS_ENTRY_PAYMENT_MAX         460
# 9                                  AMT_GOODS_PRICE         442
# 10                                 DAYS_ID_PUBLISH         438
# 11                              DAYS_EMPLOYED_PERC         417
# 12                                 INSTAL_DPD_MEAN         415
# 13                  ACTIVE_DAYS_CREDIT_ENDDATE_MIN         415
# 14                             ANNUITY_INCOME_PERC         412
# 15                       APPROVED_CNT_PAYMENT_MEAN         408
# 16                          CLOSED_DAYS_CREDIT_MAX         395
# 17                               DAYS_REGISTRATION         362
# 18                      REGION_POPULATION_RELATIVE         359
# 19                                      AMT_CREDIT         351
# 20                          INSTAL_AMT_PAYMENT_SUM         345
# 21                BURO_AMT_CREDIT_MAX_OVERDUE_MEAN         343
# 22                  CLOSED_DAYS_CREDIT_ENDDATE_MAX         340
# 23                            BURO_DAYS_CREDIT_MAX         338
# 24                           PREV_CNT_PAYMENT_MEAN         337
# 25                              INCOME_CREDIT_PERC         322
# 26                    BURO_DAYS_CREDIT_ENDDATE_MAX         318
# 27                 ACTIVE_DAYS_CREDIT_ENDDATE_MEAN         316
# 28                                  INSTAL_DBD_SUM         315
# 29                          DAYS_LAST_PHONE_CHANGE         313
# ..                                             ...         ...
# 120                         REFUSED_AMT_CREDIT_MIN         150
# 121                   APPROVED_AMT_GOODS_PRICE_MIN         149
# 122         PREV_NAME_CONTRACT_STATUS_Refused_MEAN         149
# 123                        BURO_STATUS_0_MEAN_MEAN         147
# 124                   BURO_AMT_CREDIT_SUM_DEBT_SUM         146
# 125                        APPROVED_AMT_CREDIT_MAX         146
# 126                                 INSTAL_DPD_MAX         144
# 127  PREV_WEEKDAY_APPR_PROCESS_START_THURSDAY_MEAN         143
# 128                 CLOSED_DAYS_CREDIT_ENDDATE_MIN         142
# 129                       PREV_AMT_GOODS_PRICE_MIN         141
# 130                     REFUSED_DAYS_DECISION_MEAN         141
# 131             CLOSED_AMT_CREDIT_MAX_OVERDUE_MEAN         140
# 132                   APPROVED_APP_CREDIT_PERC_MAX         139
# 133                   APPROVED_APP_CREDIT_PERC_MIN         138
# 134           APPROVED_HOUR_APPR_PROCESS_START_MAX         136
# 135               CC_CNT_DRAWINGS_ATM_CURRENT_MEAN         136
# 136                        APPROVED_AMT_CREDIT_MIN         135
# 137                      PREV_AMT_APPLICATION_MEAN         134
# 138                                 TOTALAREA_MODE         134
# 139                       APPROVED_AMT_ANNUITY_MAX         133
# 140                   BURO_AMT_CREDIT_SUM_DEBT_MAX         133
# 141                           PREV_CNT_PAYMENT_SUM         132
# 142          BURO_CREDIT_TYPE_Consumer credit_MEAN         129
# 143    PREV_WEEKDAY_APPR_PROCESS_START_MONDAY_MEAN         129
# 144                    CC_CNT_DRAWINGS_CURRENT_VAR         129
# 145                 PREV_NAME_CLIENT_TYPE_New_MEAN         128
# 146                 BURO_CREDIT_ACTIVE_Active_MEAN         126
# 147                           PREV_AMT_ANNUITY_MAX         125
# 148                                 INSTAL_DPD_SUM         125
# 149                                POS_SK_DPD_MEAN         125
#
# [150 rows x 2 columns]

# %%
index['feature']
# Out:
# 0                                       PAYMENT_RATE
# 1                                       EXT_SOURCE_3
# 2                                       EXT_SOURCE_1
# 3                                       EXT_SOURCE_2
# 4                                         DAYS_BIRTH
# 5                                      DAYS_EMPLOYED
# 6                                        AMT_ANNUITY
# 7                             ACTIVE_DAYS_CREDIT_MAX
# 8                      INSTAL_DAYS_ENTRY_PAYMENT_MAX
# 9                                    AMT_GOODS_PRICE
# 10                                   DAYS_ID_PUBLISH
# 11                                DAYS_EMPLOYED_PERC
# 12                                   INSTAL_DPD_MEAN
# 13                    ACTIVE_DAYS_CREDIT_ENDDATE_MIN
# 14                               ANNUITY_INCOME_PERC
# 15                         APPROVED_CNT_PAYMENT_MEAN
# 16                            CLOSED_DAYS_CREDIT_MAX
# 17                                 DAYS_REGISTRATION
# 18                        REGION_POPULATION_RELATIVE
# 19                                        AMT_CREDIT
# 20                            INSTAL_AMT_PAYMENT_SUM
# 21                  BURO_AMT_CREDIT_MAX_OVERDUE_MEAN
# 22                    CLOSED_DAYS_CREDIT_ENDDATE_MAX
# 23                              BURO_DAYS_CREDIT_MAX
# 24                             PREV_CNT_PAYMENT_MEAN
# 25                                INCOME_CREDIT_PERC
# 26                      BURO_DAYS_CREDIT_ENDDATE_MAX
# 27                   ACTIVE_DAYS_CREDIT_ENDDATE_MEAN
# 28                                    INSTAL_DBD_SUM
# 29                            DAYS_LAST_PHONE_CHANGE
#                            ...
# 120                           REFUSED_AMT_CREDIT_MIN
# 121                     APPROVED_AMT_GOODS_PRICE_MIN
# 122           PREV_NAME_CONTRACT_STATUS_Refused_MEAN
# 123                          BURO_STATUS_0_MEAN_MEAN
# 124                     BURO_AMT_CREDIT_SUM_DEBT_SUM
# 125                          APPROVED_AMT_CREDIT_MAX
# 126                                   INSTAL_DPD_MAX
# 127    PREV_WEEKDAY_APPR_PROCESS_START_THURSDAY_MEAN
# 128                   CLOSED_DAYS_CREDIT_ENDDATE_MIN
# 129                         PREV_AMT_GOODS_PRICE_MIN
# 130                       REFUSED_DAYS_DECISION_MEAN
# 131               CLOSED_AMT_CREDIT_MAX_OVERDUE_MEAN
# 132                     APPROVED_APP_CREDIT_PERC_MAX
# 133                     APPROVED_APP_CREDIT_PERC_MIN
# 134             APPROVED_HOUR_APPR_PROCESS_START_MAX
# 135                 CC_CNT_DRAWINGS_ATM_CURRENT_MEAN
# 136                          APPROVED_AMT_CREDIT_MIN
# 137                        PREV_AMT_APPLICATION_MEAN
# 138                                   TOTALAREA_MODE
# 139                         APPROVED_AMT_ANNUITY_MAX
# 140                     BURO_AMT_CREDIT_SUM_DEBT_MAX
# 141                             PREV_CNT_PAYMENT_SUM
# 142            BURO_CREDIT_TYPE_Consumer credit_MEAN
# 143      PREV_WEEKDAY_APPR_PROCESS_START_MONDAY_MEAN
# 144                      CC_CNT_DRAWINGS_CURRENT_VAR
# 145                   PREV_NAME_CLIENT_TYPE_New_MEAN
# 146                   BURO_CREDIT_ACTIVE_Active_MEAN
# 147                             PREV_AMT_ANNUITY_MAX
# 148                                   INSTAL_DPD_SUM
# 149                                  POS_SK_DPD_MEAN
# Name: feature, Length: 150, dtype: object

# %%
df_new = df[index.feature]

# %%
df_new.shape
# Out:
# (356251, 150)

# %% [markdown]
# Chech the NAN values in new dataframe.

# %%
# checking missing data
total = df_new.isnull().sum().sort_values(ascending = False)
percent = (df_new.isnull().sum()/df.isnull().count()*100).sort_values(ascending = False)
missing_data  = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(40)
# Out:
#                                        Total    Percent
# ACTIVE_AMT_ANNUITY_MAX                   NaN        NaN
# ACTIVE_AMT_ANNUITY_MEAN                  NaN        NaN
# ACTIVE_AMT_CREDIT_MAX_OVERDUE_MEAN  223254.0  62.667614
# ACTIVE_AMT_CREDIT_SUM_DEBT_MAX      116391.0  32.671066
# ACTIVE_AMT_CREDIT_SUM_DEBT_MEAN     116391.0  32.671066
# ACTIVE_AMT_CREDIT_SUM_DEBT_SUM      104440.0  29.316409
# ACTIVE_AMT_CREDIT_SUM_LIMIT_MEAN    138151.0  38.779119
# ACTIVE_AMT_CREDIT_SUM_LIMIT_SUM          NaN        NaN
# ACTIVE_AMT_CREDIT_SUM_MAX           104443.0  29.317251
# ACTIVE_AMT_CREDIT_SUM_MEAN          104443.0  29.317251
# ACTIVE_AMT_CREDIT_SUM_OVERDUE_MEAN       NaN        NaN
# ACTIVE_AMT_CREDIT_SUM_SUM           104440.0  29.316409
# ACTIVE_CNT_CREDIT_PROLONG_SUM            NaN        NaN
# ACTIVE_CREDIT_DAY_OVERDUE_MAX            NaN        NaN
# ACTIVE_CREDIT_DAY_OVERDUE_MEAN           NaN        NaN
# ACTIVE_DAYS_CREDIT_ENDDATE_MAX      114909.0  32.255067
# ACTIVE_DAYS_CREDIT_ENDDATE_MEAN     114909.0  32.255067
# ACTIVE_DAYS_CREDIT_ENDDATE_MIN      114909.0  32.255067
# ACTIVE_DAYS_CREDIT_MAX              104440.0  29.316409
# ACTIVE_DAYS_CREDIT_MEAN             104440.0  29.316409

# %%
missing_data.head(40)
# Out:
#                                        Total    Percent
# ACTIVE_AMT_ANNUITY_MAX                   NaN        NaN
# ACTIVE_AMT_ANNUITY_MEAN                  NaN        NaN
# ACTIVE_AMT_CREDIT_MAX_OVERDUE_MEAN  223254.0  62.667614
# ACTIVE_AMT_CREDIT_SUM_DEBT_MAX      116391.0  32.671066
# ACTIVE_AMT_CREDIT_SUM_DEBT_MEAN     116391.0  32.671066
# ACTIVE_AMT_CREDIT_SUM_DEBT_SUM      104440.0  29.316409
# ACTIVE_AMT_CREDIT_SUM_LIMIT_MEAN    138151.0  38.779119
# ACTIVE_AMT_CREDIT_SUM_LIMIT_SUM          NaN        NaN
# ACTIVE_AMT_CREDIT_SUM_MAX           104443.0  29.317251
# ACTIVE_AMT_CREDIT_SUM_MEAN          104443.0  29.317251
# ACTIVE_AMT_CREDIT_SUM_OVERDUE_MEAN       NaN        NaN
# ACTIVE_AMT_CREDIT_SUM_SUM           104440.0  29.316409
# ACTIVE_CNT_CREDIT_PROLONG_SUM            NaN        NaN
# ACTIVE_CREDIT_DAY_OVERDUE_MAX            NaN        NaN
# ACTIVE_CREDIT_DAY_OVERDUE_MEAN           NaN        NaN
# ACTIVE_DAYS_CREDIT_ENDDATE_MAX      114909.0  32.255067
# ACTIVE_DAYS_CREDIT_ENDDATE_MEAN     114909.0  32.255067
# ACTIVE_DAYS_CREDIT_ENDDATE_MIN      114909.0  32.255067
# ACTIVE_DAYS_CREDIT_MAX              104440.0  29.316409
# ACTIVE_DAYS_CREDIT_MEAN             104440.0  29.316409
# ACTIVE_DAYS_CREDIT_MIN              104440.0  29.316409
# ACTIVE_DAYS_CREDIT_UPDATE_MEAN      104440.0  29.316409
# ACTIVE_DAYS_CREDIT_VAR              189928.0  53.312973
# ACTIVE_MONTHS_BALANCE_MAX_MAX            NaN        NaN
# ACTIVE_MONTHS_BALANCE_MIN_MIN            NaN        NaN
# ACTIVE_MONTHS_BALANCE_SIZE_MEAN          NaN        NaN
# ACTIVE_MONTHS_BALANCE_SIZE_SUM           NaN        NaN
# AMT_ANNUITY                             36.0   0.010105
# AMT_CREDIT                               0.0   0.000000
# AMT_GOODS_PRICE                        278.0   0.078035
# AMT_INCOME_TOTAL                         0.0   0.000000
# AMT_REQ_CREDIT_BUREAU_DAY                NaN        NaN
# AMT_REQ_CREDIT_BUREAU_HOUR               NaN        NaN
# AMT_REQ_CREDIT_BUREAU_MON                NaN        NaN
# AMT_REQ_CREDIT_BUREAU_QRT                NaN        NaN
# AMT_REQ_CREDIT_BUREAU_WEEK               NaN        NaN
# AMT_REQ_CREDIT_BUREAU_YEAR               NaN        NaN
# ANNUITY_INCOME_PERC                     36.0   0.010105
# APARTMENTS_AVG                           NaN        NaN
# APARTMENTS_MEDI                          NaN        NaN

# %%
df_new.fillna(-999)
# Out:
#         PAYMENT_RATE  EXT_SOURCE_3  EXT_SOURCE_1  EXT_SOURCE_2  DAYS_BIRTH  \
# 0           0.060749      0.139376      0.083037      0.262949       -9461
# 1           0.027598   -999.000000      0.311267      0.622246      -16765
# 2           0.050000      0.729567   -999.000000      0.555912      -19046
# 3           0.094941   -999.000000   -999.000000      0.650442      -19005
# 4           0.042623   -999.000000   -999.000000      0.322738      -19932
# 5           0.056101      0.621226   -999.000000      0.354225      -16941
# 6           0.026463      0.492060      0.774761      0.724000      -13778
# 7           0.027500      0.540654   -999.000000      0.714279      -18850
# 8           0.033176      0.751724      0.587334      0.205747      -20099
# 9           0.050000   -999.000000   -999.000000      0.746644      -14469
# 10          0.032455      0.363945      0.319760      0.651862      -10197
# 11          0.071975      0.652897      0.722044      0.555183      -20417
# 12          0.072732      0.176653      0.464831      0.715042      -13439
# 13          0.031538      0.770087   -999.000000      0.566907      -14086
# 14          0.042366   -999.000000      0.721940      0.642656      -14583
# 15          0.067251      0.678568      0.115634      0.346634       -8728
# 16          0.051314      0.062103   -999.000000      0.236378      -12931
# 17          0.050000   -999.000000   -999.000000      0.683513       -9776
# 18          0.050000      0.556727   -999.000000      0.706428      -17718
# 19          0.032257      0.477649   -999.000000      0.586617      -11348
# 20          0.050000   -999.000000      0.565655      0.113375      -18252
# 21          0.033165      0.542445      0.437709      0.233767      -14815
# 22          0.065367      0.358951   -999.000000      0.457143      -11146
# 23          0.099437      0.669057   -999.000000      0.624305      -24827
# 24          0.051327      0.565608   -999.000000      0.786179      -11286
# 25          0.049220      0.461482      0.561948      0.651406      -19334
# 26          0.027629      0.190706   -999.000000      0.548477      -18724
# 27          0.072862      0.659406   -999.000000      0.541124      -15948
# 28          0.072932      0.524496      0.600396      0.685011       -9994
# 29          0.050000   -999.000000      0.297914      0.502779      -10341
# ...              ...           ...           ...           ...         ...
# 356221      0.079241      0.627991      0.623896      0.544646      -11987
# 356222      0.063910      0.659406      0.554915      0.654740      -17293
# 356223      0.051462   -999.000000      0.361450      0.008777      -12607
# 356224      0.074750      0.483050      0.725281      0.549354      -23732
# 356225      0.054250      0.614414   -999.000000      0.540945      -14237
# 356226      0.051244      0.698668      0.498882      0.350273      -10667
# 356227      0.071522      0.612704      0.587915      0.554481      -12970
# 356228      0.079280      0.417100      0.204548      0.664593       -8082
# 356229      0.079784   -999.000000   -999.000000      0.385043      -16506
# 356230      0.051471      0.073965      0.448657      0.689392      -15051
# 356231      0.034403      0.295583      0.478887      0.387059      -15847
# 356232      0.054540      0.687933      0.642719      0.095077      -20464
# 356233      0.037829      0.508287      0.563175      0.565268      -16710
# 356234      0.102448      0.631355      0.574515      0.287920      -15884
# 356235      0.056025      0.556727      0.787271      0.635018      -20898
# 356236      0.118667   -999.000000   -999.000000      0.590742      -13165
# 356237      0.091720      0.459690      0.440056      0.408147      -16019
# 356238      0.064200      0.733815      0.573130      0.432684      -20536
# 356239      0.113368      0.415347      0.527067      0.210374      -17716
# 356240      0.036042      0.834784      0.363857      0.347457      -20003
# 356241      0.055835      0.569149      0.410389      0.472553      -11387
# 356242      0.067990   -999.000000   -999.000000      0.465881      -22995
# 356243      0.097680      0.631355      0.851722      0.471719      -21780
# 356244      0.079363      0.255332      0.442558      0.689832      -19397
# 356245      0.091706      0.240541      0.174671      0.762352      -11708
# 356246      0.042354      0.643026   -999.000000      0.648575      -19970
# 356247      0.051267   -999.000000   -999.000000      0.684596      -11186
# 356248      0.105414      0.283712      0.733503      0.632770      -15922
# 356249      0.055840      0.595456      0.373090      0.445701      -13968
# 356250      0.079003      0.272134   -999.000000      0.456541      -13962
#
#         DAYS_EMPLOYED  AMT_ANNUITY  ACTIVE_DAYS_CREDIT_MAX  \
# 0              -637.0      24700.5                  -103.0
# 1             -1188.0      35698.5                  -606.0
# 2              -225.0       6750.0                  -999.0
# 3             -3039.0      29686.5                  -999.0
# 4             -3038.0      21865.5                  -999.0
# 5             -1588.0      27517.5                   -78.0
# 6             -3130.0      41301.0                  -239.0
# 7              -449.0      42075.0                 -1138.0
# 8              -999.0      33826.5                  -999.0
# 9             -2019.0      20250.0                  -999.0
# 10             -679.0      21177.0                  -376.0
# 11             -999.0      10678.5                  -999.0
# 12            -2717.0       5881.5                  -128.0
# 13            -3028.0      28966.5                  -999.0
# 14             -203.0      32778.0                  -999.0
# 15            -1157.0      20160.0                  -495.0
# 16            -1317.0      26149.5                   -90.0
# 17             -191.0      13500.0                  -999.0
# 18            -7804.0       7875.0                  -289.0
# 19            -2038.0      17563.5                  -157.0
# 20            -4286.0      21375.0                  -999.0
# 21            -1652.0      37561.5                  -700.0
# 22            -4306.0      32521.5                  -148.0
# 23             -999.0      23850.0                  -143.0
# 24             -746.0      12703.5                  -110.0
# 25            -3494.0      11074.5                  -418.0
# 26            -2628.0      27076.5                   -75.0
# 27            -1234.0      23827.5                  -556.0
# 28            -1796.0      57676.5                  -195.0
# 29            -1010.0       9000.0                  -999.0
# ...               ...          ...                     ...
# 356221        -1745.0      43366.5                  -194.0
# 356222        -4836.0      57519.0                  -223.0
# 356223        -2283.0      16398.0                  -999.0
# 356224         -999.0      13455.0                 -1069.0
# 356225        -4931.0      19530.0                  -379.0
# 356226        -1979.0      35374.5                  -995.0
# 356227         -305.0      23134.5                  -494.0
# 356228        -1309.0      37129.5                   -92.0
# 356229        -1310.0      13284.0                  -471.0
# 356230        -2819.0      16213.5                  -184.0
# 356231        -2191.0      17707.5                  -391.0
# 356232        -3727.0      24543.0                  -113.0
# 356233        -2196.0      37917.0                  -227.0
# 356234        -6551.0      15291.0                 -1812.0
# 356235         -999.0      38398.5                  -961.0
# 356236        -1564.0      16020.0                  -999.0
# 356237        -3759.0      40824.0                   -92.0
# 356238         -999.0      28890.0                  -999.0
# 356239        -1896.0      54382.5                  -999.0
# 356240        -3684.0      37764.0                 -1539.0
# 356241         -846.0      46660.5                  -999.0
# 356242         -999.0       7411.5                  -999.0
# 356243         -999.0      48888.0                 -2751.0
# 356244         -119.0      28570.5                  -438.0
# 356245         -369.0      23112.0                  -165.0
# 356246        -5169.0      17473.5                  -303.0
# 356247        -1149.0      31909.5                  -999.0
# 356248        -3037.0      33205.5                  -229.0
# 356249        -2731.0      25128.0                  -890.0
# 356250         -633.0      24709.5                  -760.0
#
#         INSTAL_DAYS_ENTRY_PAYMENT_MAX  AMT_GOODS_PRICE  ...  \
# 0                               -49.0         351000.0  ...
# 1                              -544.0        1129500.0  ...
# 2                              -727.0         135000.0  ...
# 3                               -12.0         297000.0  ...
# 4                               -14.0         513000.0  ...
# 5                               -82.0         454500.0  ...
# 6                               -58.0        1395000.0  ...
# 7                              -774.0        1530000.0  ...
# 8                               -37.0         913500.0  ...
# 9                              -151.0         405000.0  ...
# 10                              -36.0         652500.0  ...
# 11                            -2108.0         135000.0  ...
# 12                             -539.0          67500.0  ...
# 13                              -21.0         697500.0  ...
# 14                              -40.0         679500.0  ...
# 15                             -716.0         247500.0  ...
# 16                              -35.0         387000.0  ...
# 17                              -66.0         270000.0  ...
# 18                              -51.0         157500.0  ...
# 19                             -166.0         454500.0  ...
# 20                             -999.0         427500.0  ...
# 21                             -697.0         927000.0  ...
# 22                             -425.0         450000.0  ...
# 23                             -116.0         225000.0  ...
# 24                             -224.0         247500.0  ...
# 25                             -233.0         225000.0  ...
# 26                             -999.0         702000.0  ...
# 27                            -1307.0         270000.0  ...
# 28                             -495.0         675000.0  ...
# 29                             -189.0         180000.0  ...
# ...                               ...              ...  ...
# 356221                         -372.0         495000.0  ...
# 356222                          -15.0         900000.0  ...
# 356223                          -42.0         216000.0  ...
# 356224                          -90.0         180000.0  ...
# 356225                          -21.0         360000.0  ...
# 356226                           -9.0         549000.0  ...
# 356227                         -492.0         270000.0  ...
# 356228                         -377.0         382500.0  ...
# 356229                          -34.0         166500.0  ...
# 356230                         -896.0         315000.0  ...
# 356231                          -81.0         387000.0  ...
# 356232                          -10.0         450000.0  ...
# 356233                         -105.0         846000.0  ...
# 356234                          -69.0         135000.0  ...
# 356235                          -18.0         585000.0  ...
# 356236                        -1245.0         135000.0  ...
# 356237                         -999.0         405000.0  ...
# 356238                          -40.0         450000.0  ...
# 356239                           -9.0         450000.0  ...
# 356240                         -291.0         904500.0  ...
# 356241                         -470.0         765000.0  ...
# 356242                          -35.0          90000.0  ...
# 356243                         -441.0         450000.0  ...
# 356244                          -24.0         360000.0  ...
# 356245                           -6.0         217561.5  ...
# 356246                         -599.0         270000.0  ...
# 356247                          -56.0         495000.0  ...
# 356248                          -33.0         315000.0  ...
# 356249                          -13.0         450000.0  ...
# 356250                          -33.0         270000.0  ...
#
#         BURO_AMT_CREDIT_SUM_DEBT_MAX  PREV_CNT_PAYMENT_SUM  \
# 0                         245781.000                  24.0
# 1                              0.000                  30.0
# 2                              0.000                   4.0
# 3                           -999.000                 138.0
# 4                              0.000                 124.0
# 5                         240057.000                  56.0
# 6                         557959.500                  56.0
# 7                         348007.500                  10.0
# 8                              0.000                  42.0
# 9                           -999.000                  54.0
# 10                        420201.000                  18.0
# 11                             0.000                  10.0
# 12                         63724.500                  68.0
# 13                             0.000                  34.0
# 14                          -999.000                  40.0
# 15                        245470.140                  12.0
# 16                        117243.000                  14.0
# 17                          -999.000                  42.0
# 18                        205276.500                  18.0
# 19                         70443.000                  50.0
# 20                          -999.000                -999.0
# 21                       1886544.000                  96.0
# 22                       2542576.500                  42.0
# 23                        376713.000                  34.0
# 24                       3682287.000                   6.0
# 25                        432301.500                  69.0
# 26                       1125000.000                -999.0
# 27                             0.000                   6.0
# 28                             0.000                  12.0
# 29                          -999.000                  12.0
# ...                              ...                   ...
# 356221                   1059907.500                   6.0
# 356222                   1356467.850                  22.0
# 356223                      -999.000                  48.0
# 356224                    290605.500                  20.0
# 356225                         0.000                 114.0
# 356226                   1344043.845                 214.0
# 356227                    740776.500                  46.0
# 356228                         0.000                  14.0
# 356229                         0.000                  60.0
# 356230                    179410.500                   6.0
# 356231                   1061770.500                  66.0
# 356232                    232794.000                  64.0
# 356233                    643446.000                  70.0
# 356234                      5121.000                 108.0
# 356235                         0.000                  48.0
# 356236                      -999.000                   6.0
# 356237                    112077.000                -999.0
# 356238                         0.000                  50.0
# 356239                         0.000                  36.0
# 356240                         0.000                  78.0
# 356241                         0.000                  12.0
# 356242                      -999.000                 212.0
# 356243                         0.000                   6.0
# 356244                    697054.500                 240.0
# 356245                     15322.500                  44.0
# 356246                    278901.000                  24.0
# 356247                      -999.000                  70.0
# 356248                     21343.500                  22.0
# 356249                    380604.060                  58.0
# 356250                   1840308.480                  78.0
#
#         BURO_CREDIT_TYPE_Consumer credit_MEAN  \
# 0                                    0.500000
# 1                                    0.500000
# 2                                    1.000000
# 3                                 -999.000000
# 4                                    1.000000
# 5                                    1.000000
# 6                                    0.888889
# 7                                    0.500000
# 8                                    0.750000
# 9                                 -999.000000
# 10                                   1.000000
# 11                                   1.000000
# 12                                   0.857143
# 13                                   0.833333
# 14                                -999.000000
# 15                                   0.500000
# 16                                   1.000000
# 17                                -999.000000
# 18                                   1.000000
# 19                                   0.692308
# 20                                -999.000000
# 21                                   1.000000
# 22                                   0.666667
# 23                                   1.000000
# 24                                   0.500000
# 25                                   0.666667
# 26                                   0.714286
# 27                                   1.000000
# 28                                   0.000000
# 29                                -999.000000
# ...                                       ...
# 356221                               1.000000
# 356222                               0.333333
# 356223                            -999.000000
# 356224                               1.000000
# 356225                               0.000000
# 356226                               0.750000
# 356227                               1.000000
# 356228                               1.000000
# 356229                               0.250000
# 356230                               0.333333
# 356231                               0.857143
# 356232                               0.750000
# 356233                               0.857143
# 356234                               1.000000
# 356235                               0.750000
# 356236                            -999.000000
# 356237                               1.000000
# 356238                               1.000000
# 356239                               1.000000
# 356240                               0.500000
# 356241                               1.000000
# 356242                            -999.000000
# 356243                               1.000000
# 356244                               0.666667
# 356245                               0.200000
# 356246                               0.600000
# 356247                            -999.000000
# 356248                               0.600000
# 356249                               0.764706
# 356250                               0.666667
#
#         PREV_WEEKDAY_APPR_PROCESS_START_MONDAY_MEAN  \
# 0                                          0.000000
# 1                                          0.000000
# 2                                          0.000000
# 3                                          0.000000
# 4                                          0.166667
# 5                                          0.600000
# 6                                          0.142857
# 7                                          0.000000
# 8                                          0.250000
# 9                                          0.250000
# 10                                         0.000000
# 11                                         0.000000
# 12                                         0.500000
# 13                                         0.000000
# 14                                         0.250000
# 15                                         0.000000
# 16                                         0.500000
# 17                                         0.000000
# 18                                         0.000000
# 19                                         0.000000
# 20                                      -999.000000
# 21                                         0.500000
# 22                                         0.000000
# 23                                         0.250000
# 24                                         0.000000
# 25                                         0.000000
# 26                                      -999.000000
# 27                                         0.000000
# 28                                         1.000000
# 29                                         0.500000
# ...                                             ...
# 356221                                     0.000000
# 356222                                     0.333333
# 356223                                     0.000000
# 356224                                     0.000000
# 356225                                     0.000000
# 356226                                     0.000000
# 356227                                     0.000000
# 356228                                     0.333333
# 356229                                     0.000000
# 356230                                     0.000000
# 356231                                     0.200000
# 356232                                     0.000000
# 356233                                     0.142857
# 356234                                     0.444444
# 356235                                     0.250000
# 356236                                     0.000000
# 356237                                  -999.000000
# 356238                                     0.400000
# 356239                                     0.166667
# 356240                                     0.750000
# 356241                                     0.000000
# 356242                                     0.250000
# 356243                                     1.000000
# 356244                                     0.090909
# 356245                                     0.166667
# 356246                                     0.000000
# 356247                                     0.750000
# 356248                                     0.000000
# 356249                                     0.000000
# 356250                                     0.500000
#
#         CC_CNT_DRAWINGS_CURRENT_VAR  PREV_NAME_CLIENT_TYPE_New_MEAN  \
# 0                       -999.000000                        1.000000
# 1                       -999.000000                        0.000000
# 2                       -999.000000                        1.000000
# 3                          0.000000                        0.111111
# 4                       -999.000000                        0.166667
# 5                       -999.000000                        0.200000
# 6                       -999.000000                        0.000000
# 7                       -999.000000                        1.000000
# 8                          0.216216                        0.250000
# 9                       -999.000000                        0.250000
# 10                      -999.000000                        0.500000
# 11                      -999.000000                        1.000000
# 12                      -999.000000                        0.000000
# 13                      -999.000000                        0.500000
# 14                      -999.000000                        0.250000
# 15                      -999.000000                        1.000000
# 16                      -999.000000                        0.500000
# 17                         0.000000                        0.166667
# 18                      -999.000000                        1.000000
# 19                         0.000000                        0.000000
# 20                      -999.000000                     -999.000000
# 21                      -999.000000                        0.125000
# 22                      -999.000000                        0.333333
# 23                      -999.000000                        0.250000
# 24                      -999.000000                        1.000000
# 25                      -999.000000                        0.083333
# 26                      -999.000000                     -999.000000
# 27                      -999.000000                        1.000000
# 28                      -999.000000                        1.000000
# 29                      -999.000000                        0.500000
# ...                             ...                             ...
# 356221                  -999.000000                        1.000000
# 356222                  -999.000000                        0.333333
# 356223                  -999.000000                        0.400000
# 356224                  -999.000000                        0.111111
# 356225                  -999.000000                        0.000000
# 356226                     0.000000                        0.083333
# 356227                  -999.000000                        0.333333
# 356228                  -999.000000                        0.333333
# 356229                  -999.000000                        0.333333
# 356230                  -999.000000                        1.000000
# 356231                  -999.000000                        0.200000
# 356232                     0.575138                        0.250000
# 356233                     0.000000                        0.142857
# 356234                  -999.000000                        0.222222
# 356235                     0.314001                        0.000000
# 356236                  -999.000000                        1.000000
# 356237                  -999.000000                     -999.000000
# 356238                  -999.000000                        0.200000
# 356239                  -999.000000                        0.166667
# 356240                  -999.000000                        0.250000
# 356241                     0.000000                        0.333333
# 356242                  -999.000000                        0.125000
# 356243                  -999.000000                        0.500000
# 356244                     0.984190                        0.090909
# 356245                  -999.000000                        0.166667
# 356246                  -999.000000                        1.000000
# 356247                  -999.000000                        0.250000
# 356248                  -999.000000                        0.500000
# 356249                  -999.000000                        0.200000
# 356250                     4.060606                        0.125000
#
#         BURO_CREDIT_ACTIVE_Active_MEAN  PREV_AMT_ANNUITY_MAX  INSTAL_DPD_SUM  \
# 0                             0.250000              9251.775             0.0
# 1                             0.250000             98356.995             0.0
# 2                             0.000000              5357.250             0.0
# 3                          -999.000000             39954.510             0.0
# 4                             0.000000             22678.785            63.0
# 5                             0.333333             25309.575          1317.0
# 6                             0.222222             17341.605             7.0
# 7                             0.500000             27463.410             0.0
# 8                             0.000000             31295.250          1033.0
# 9                          -999.000000             11188.035            27.0
# 10                            0.250000             14045.625            20.0
# 11                            0.000000              7666.920            21.0
# 12                            0.571429             14480.460           261.0
# 13                            0.000000             16967.295             0.0
# 14                         -999.000000             94906.035             0.0
# 15                            1.000000             10518.615             0.0
# 16                            0.500000              8779.770             0.0
# 17                         -999.000000             33750.000            56.0
# 18                            1.000000              6765.975             0.0
# 19                            0.307692             16822.440             0.0
# 20                         -999.000000              -999.000          -999.0
# 21                            1.000000             55678.095            72.0
# 22                            0.666667             42778.845             0.0
# 23                            0.333333             28077.570             0.0
# 24                            0.250000             22891.680             0.0
# 25                            0.333333              9035.685             0.0
# 26                            0.428571              -999.000          -999.0
# 27                            0.250000              7910.145             9.0
# 28                            1.000000              5542.920           723.0
# 29                         -999.000000             22430.430             0.0
# ...                                ...                   ...             ...
# 356221                        0.500000             39286.980             0.0
# 356222                        0.333333             13851.540             0.0
# 356223                     -999.000000             24841.305             0.0
# 356224                        0.250000             16740.765             7.0
# 356225                        1.000000             16875.000             2.0
# 356226                        0.250000             36168.210             0.0
# 356227                        0.125000             12227.265             0.0
# 356228                        0.500000             17238.420             9.0
# 356229                        0.500000             20527.920             0.0
# 356230                        0.666667              2898.180             0.0
# 356231                        0.285714             20320.740           305.0
# 356232                        0.375000             20166.930             6.0
# 356233                        0.428571              8096.850             5.0
# 356234                        0.500000             16466.490             0.0
# 356235                        0.250000             53174.880           255.0
# 356236                     -999.000000             26377.605            44.0
# 356237                        0.500000              -999.000          -999.0
# 356238                        0.000000             18978.840            54.0
# 356239                        0.000000              9357.345            44.0
# 356240                        0.500000              9876.510             0.0
# 356241                        0.000000             14880.060             0.0
# 356242                     -999.000000             27574.470            53.0
# 356243                        0.333333              8453.070             0.0
# 356244                        0.500000             29250.000             7.0
# 356245                        0.800000             21001.500             1.0
# 356246                        0.400000             14222.430             0.0
# 356247                     -999.000000             14571.765            38.0
# 356248                        0.200000             15761.205             0.0
# 356249                        0.352941             23451.705             1.0
# 356250                        0.666667             26474.625            21.0
#
#         POS_SK_DPD_MEAN
# 0              0.000000
# 1              0.000000
# 2              0.000000
# 3              0.000000
# 4              0.000000
# 5            339.060241
# 6              0.000000
# 7              0.000000
# 8            205.666667
# 9              0.000000
# 10             0.000000
# 11             1.181818
# 12             0.000000
# 13             0.000000
# 14             0.000000
# 15             0.000000
# 16             0.000000
# 17             0.000000
# 18             0.000000
# 19             0.000000
# 20          -999.000000
# 21             0.000000
# 22             0.000000
# 23             0.000000
# 24             0.000000
# 25             0.000000
# 26          -999.000000
# 27             0.000000
# 28             2.461538
# 29             0.000000
# ...                 ...
# 356221         0.000000
# 356222         0.000000
# 356223         0.000000
# 356224         0.000000
# 356225         0.000000
# 356226         0.000000
# 356227         0.000000
# 356228         0.750000
# 356229         0.000000
# 356230         0.000000
# 356231         1.656716
# 356232         0.033333
# 356233         0.000000
# 356234         0.000000
# 356235         0.000000
# 356236         1.000000
# 356237      -999.000000
# 356238         0.000000
# 356239         0.031250
# 356240         0.000000
# 356241         0.000000
# 356242         0.263158
# 356243         0.000000
# 356244         0.000000
# 356245         0.000000
# 356246         0.000000
# 356247         0.000000
# 356248         0.000000
# 356249         0.000000
# 356250         0.000000
#
# [356251 rows x 150 columns]

# %% [markdown]
# ## Model Building

# %%
test_df = pd.read_csv(path+'/application_test.csv')

# %%
test_df.shape
# Out:
# (48744, 121)

# %%
df = pd.read_csv(path+'/application_train.csv')

# %%
df.shape
# Out:
# (307511, 122)

# %%
df.
